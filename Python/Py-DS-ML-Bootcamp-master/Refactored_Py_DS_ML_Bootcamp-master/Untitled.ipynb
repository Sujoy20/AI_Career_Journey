# %%
print('hello')
# Out:
# hello

# %%
1+1
# Out:
# 2

# %%
print(1+1)
# Out:
# 2

# %%
Name = 'Sujoy'
num=12

# %%
print('My name is {} and my fav numb : {}'.format(Name,num))
# Out:
# My name is Sujoy and my fav numb : 12

# %%
#Strings
